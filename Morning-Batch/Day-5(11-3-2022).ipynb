# %% [markdown]
# ### Strings
# - Collection of characters or Sequence of characters or Set of characters.
# - we can define a string by using single , double or triple quotes.
#     - single or double --> single line strings
#     - triple  --> multiline strings.

# %%
s1 = 'python workshop'
s2 = "this is a single line string"

# %%
print(s1)
# Out:
# python workshop

# %%
print(s2)
# Out:
# this is a single line string

# %%
s3 = '''This is
the last session
of this workshop.'''
print(s3)
# Out:
# This is
# the last session
# of this workshop.

# %%
s4 = """this is
also a multi
line string"""
print(s4)
# Out:
# this is
# also a multi
# line string

# %%
for i in s4:
    print(i)
# Out:
# t
# h
# i
# s
#
# i
# s
#
#
# a
# l
# s
# o
#
# a
#
# m
# u
# l
# t
# i
#
#
# l
# i
# n
# e
#
# s
# t
# r
# i
# n
# g

# %%
first_name = input("Enter ur firstname")
last_name = input("Enter ur lastname")
# string concatenation --> adding two strings
print(first_name+' '+last_name)
# Out:
# Enter ur firstnamejohn
# Enter ur lastnamesmith
# john smith

# %%
# 'vits' i want to print this string 6 times
'vits '*6
# Out:
# 'vits vits vits vits vits vits '

# %% [markdown]
# ### String indexing and slicing
# - string indexing starts from 0
# - types of indexing:
#     1. positive or forward indexing
#         - left to right
#         - index starts from 0 to end of the string
#     2. negative or backward indexing
#         - from right ot left
#         - index starts from -1
#
# - str_name[index_value]
# - Immutable object.

# %% [markdown]
# ### Immutable vs Mutable
# - Immutable : We can't change or modify anything after it's declaration.
#     - integers
#     - float values
#     - strings
#     - tuple
# - Mutable : We can update or add or delete anything from the given object at any time.
#     - lists
#     - sets
#     - dictionaries

# %%
s = 'visvodaya institute'
s[4] # positive
s[-15] # _ve
# Out:
# 'o'

# %%
s[-4]
s[15]
# Out:
# 't'

# %% [markdown]
# ### Slicing
# - slicing means dividing the main string into sub-strings.
# - str_name[index] --> it will return char at index
# - str_name[start:end] --> it will return sequence of characters from start index to (end-1) index.
# - str_name[start:end:incre/decre]

# %%
print(s)
# Out:
# visvodaya institute

# %%
s[1:3]
# Out:
# 'is'

# %%
s[5:9]
# Out:
# 'daya'

# %%
# a i
s[8:11]
# Out:
# 'a i'

# %%
print(s)
# Out:
# visvodaya institute

# %%
# a i using negative indexing
s[-11:-8]
# Out:
# 'a i'

# %%
s[-8:-11]
# Out:
# ''

# %%
s[:6] # by default starts from 0
# Out:
# 'visvod'

# %%
s[8:] # default end value is len(s)-1
# Out:
# 'a institute'

# %%
# len() --> it will return the total number of
# characters present in the given string.
len('hello world!')
# Out:
# 12

# %%
max(s) # return the char with highest ascii value
# Out:
# 'y'

# %%
min(s)
# Out:
# ' '

# %%
ord(' ')
# Out:
# 32

# %%
l = 'andhra pradesh'
l[8:13] # rades
l[-6:-1] #rades
# Out:
# 'rades'

# %%
l[:]
# Out:
# 'andhra pradesh'

# %%
l[0::]
# Out:
# 'andhra pradesh'

# %%
l[:15]
# Out:
# 'andhra pradesh'

# %%
l
# Out:
# 'andhra pradesh'

# %%
l[::2]
# Out:
# 'adr rds'

# %%
l[1::2]
# Out:
# 'nhapaeh'

# %%
# heapahn
l[::-2]
# Out:
# 'heapahn'

# %%
l
# Out:
# 'andhra pradesh'

# %%
l[-14:-8:3] #ah
# Out:
# 'ah'

# %%
l[-2:-10:-4] #
# Out:
# 'sr'

# %%
l[::-1]
# Out:
# 'hsedarp arhdna'

# %%
pop
lol
wow
mom
dad
tenet
level
eye
malayalam
racecar

# %%
s = input("Enter any string: ")
if s==s[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter any string: levels
# Not a palindrome

# %% [markdown]
# ### String methods
# - dir(str)
# - str_name.method_name(parameters)

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
a = 'elEctroNICs AND cOMMUnicatiON EnGIneErinG'
len(a) #
# Out:
# 41

# %%
a.index('i')
# Out:
# 22

# %%
a.index('i',23,30)
# Out:
# 26

# %%
a.rindex('i')
# Out:
# 38

# %%
a.index('q') # left to right
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2932\1923805997.py in <module>
# ----> 1 a.index('q') # left to right
#
# ValueError: substring not found

# %%
a.rindex('E') # right to left
# Out:
# 18

# %%
a.index('elE')
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a
# Out:
# 'elEctroNICs AND cOMMUnicatiON EnGIneErinG'

# %%
a.rfind('G')
# Out:
# 40

# %%
a.find('G')
# Out:
# 32

# %%
a.find('Cs')
# Out:
# 9

# %%
a.rfind('Cs')
# Out:
# 9

# %%
# count() --> it will return the number of 
# occurances of particular character.
a.count('E')
# Out:
# 3

# %%
a.count('r')
# Out:
# 2

# %%
a.count('M')
# Out:
# 2

# %%
# capitalize()
a.capitalize()
# Out:
# 'Electronics and communication engineering'

# %%
a.upper()
# Out:
# 'ELECTRONICS AND COMMUNICATION ENGINEERING'

# %%
a.lower()
# Out:
# 'electronics and communication engineering'

# %%
a.swapcase()
# Out:
# 'ELeCTROnicS and CommuNICATIon eNgiNEeRINg'

# %%
s = "cOmmUnication enGineEriNg"
s.title()
# Out:
# 'Communication Engineering'

# %%
s.split()
# Out:
# ['cOmmUnication', 'enGineEriNg']

# %%
a
# Out:
# 'elEctroNICs AND cOMMUnicatiON EnGIneErinG'

# %%
a.split()
# Out:
# ['elEctroNICs', 'AND', 'cOMMUnicatiON', 'EnGIneErinG']

# %%
a.split('c')
# Out:
# ['elE', 'troNICs AND ', 'OMMUni', 'atiON EnGIneErinG']

# %%
a.split('E',8)
# Out:
# ['el', 'ctroNICs AND cOMMUnicatiON ', 'nGIne', 'rinG']

# %%
a.partition('c')
# Out:
# ('elE', 'c', 'troNICs AND cOMMUnicatiON EnGIneErinG')

# %%
a.rpartition('c')
# Out:
# ('elEctroNICs AND cOMMUni', 'c', 'atiON EnGIneErinG')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
k = '   vits college   '
k.strip()
# Out:
# 'vits college'

# %%
k.lstrip()
# Out:
# 'vits college   '

# %%
k.rstrip()
# Out:
# '   vits college'

# %%
j = '@@@  @@hello vits@  @@'
j = j.strip('@')

# %%
print(j)
# Out:
#   @@hello vits@

# %%
v = 'nellore'
'*&%*'.join(v)
# Out:
# 'n*&%*e*&%*l*&%*l*&%*o*&%*r*&%*e'

# %%
k
# Out:
# '   vits college   '

# %%
k.replace(' ','!')
# Out:
# '!!!vits!college!!!'

# %%
k.replace(' ','')
# Out:
# 'vitscollege'

# %%
print(k)
# Out:
#    vits college

# %%
# center,zfill,ljust,rjust
c = 'visvodaya'
c.zfill(10)
# Out:
# '0visvodaya'

# %%
c.zfill(20)
# Out:
# '00000000000visvodaya'

# %%
c.zfill(6)
# Out:
# 'visvodaya'

# %%
c.center(16,'*')
# Out:
# '***visvodaya****'

# %%
c.center(21,'%')
# Out:
# '%%%%%%visvodaya%%%%%%'

# %%
c.center(12,'@')
# Out:
# '@visvodaya@@'

# %%
c.ljust(25)
# Out:
# 'visvodaya                '

# %%
c.rjust(23)
# Out:
# '              visvodaya'

# %%
c.rjust(24,'O')
# Out:
# 'OOOOOOOOOOOOOOOvisvodaya'

# %%
c.ljust(21,'O')
# Out:
# 'visvodayaOOOOOOOOOOOO'

# %%
c
# Out:
# 'visvodaya'

# %% [markdown]
# - islower()
# - isupper()
# - isalpha()
# - isalnum()
# - isdigit()
# - isnumeric()
# - isspace()
# - isidentifier()
# - istitle()
# - isprintable()

# %%
'Python 3.10'.islower()
# Out:
# False

# %%
'PYTHoN 3.10'.isupper()
# Out:
# False

# %%
s = 'TehcHNoLoGy'
for i in s:
    if i.isupper():
        print(i,end=" ")
# Out:
# T H N L G

# %%
s = 'TehcHNoLoGy'
c = 0
for i in s:
    if i.islower():
        c+=1
print(c)
# Out:
# 6

# %%
l.isupper()
# Out:
# False

# %%
'hEloo'.isupper()
# Out:
# False

# %%
' '.isspace()
# Out:
# True

# %%
'Python3.10'.isalpha()
# Out:
# False

# %%
'Python310'.isalnum()
# Out:
# True

# %%
'Python3.10'.isalnum()
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p = 'pbr'
p[2]
# Out:
# 'r'

# %% [markdown]
# ## Data Structures in python
# - List
# - Tuple
# - Set
# - Dictionaries

# %% [markdown]
# ### Lists
#
# ![image.png](attachment:image.png)

# %%
l = [16,42,93,44,5.44,16,44,'mercy','avin','green','avin']
print(l)
# Out:
# [16, 42, 93, 44, 5.44, 16, 44, 'mercy', 'avin', 'green', 'avin']

# %%
l[0]
# Out:
# 16

# %%
l[4:8]
# Out:
# [5.44, 16, 44, 'mercy']

# %%
type(l)
# Out:
# list

# %%
l[::-2]
# Out:
# ['avin', 'avin', 44, 5.44, 93, 16]

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
l.append(100)

# %%
print(l)
# Out:
# [16, 42, 93, 44, 5.44, 16, 44, 'mercy', 'avin', 'green', 'avin', 100, 'pink', 'white', ['pink', 'white']]

# %%
l.extend(['pink','white'])

# %%
l.append(['pink','white'])

# %%
l[-1]
# Out:
# ['pink', 'white']

# %%
l.insert(10,1000)

# %%
print(l)
# Out:
# [16, 42, 93, 44, 5.44, 16, 44, 'mercy', 'avin', 'green', 1000, 'avin', 100, 'pink', 'white', ['pink', 'white']]

# %%
l[3] = 'vits'
print(l)
# Out:
# [16, 42, 93, 'vits', 5.44, 16, 44, 'mercy', 'avin', 'green', 1000, 'avin', 100, 'pink', 'white', ['pink', 'white']]

# %%
print(l)
# Out:
# [42, 93, 'vits', 5.44, 16, 44, 'mercy', 'green', 1000, 'avin', 100]

# %%
l.pop()
# Out:
# 'pink'

# %%
l.remove('16')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1948\3269855383.py in <module>
# ----> 1 l.remove('16')
#
# ValueError: list.remove(x): x not in list

# %%
l.remove(16)

# %% [markdown]
# ## Tuple
#
# ![image.png](attachment:image.png)

# %%
t= (1,2,3,4,5)
print(t)
# Out:
# (1, 2, 3, 4, 5)

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t.index(4)
# Out:
# 3

# %%
names = ('nandini','lakshman','seshu','yogi','mrudula','poojitha')
print(names)
# Out:
# ('nandini', 'lakshman', 'seshu', 'yogi', 'mrudula', 'poojitha')

# %%
names.index('yogi')
# Out:
# 3

# %%
names[1:4]
# Out:
# ('lakshman', 'seshu', 'yogi')

# %%
names[::-3]
# Out:
# ('poojitha', 'seshu')

# %%
names *3
# Out:
# ('nandini',
#  'lakshman',
#  'seshu',
#  'yogi',
#  'mrudula',
#  'poojitha',
#  'nandini',
#  'lakshman',
#  'seshu',
#  'yogi',
#  'mrudula',
#  'poojitha',
#  'nandini',
#  'lakshman',
#  'seshu',
#  'yogi',
#  'mrudula',
#  'poojitha')

# %%
t+names
# Out:
# (1, 2, 3, 4, 5, 'nandini', 'lakshman', 'seshu', 'yogi', 'mrudula', 'poojitha')

# %%
for i in names:
    print(i,end=" ")
# Out:
# nandini lakshman seshu yogi mrudula poojitha

# %%
for i in range(len(names)-1,0,-1):
    if names[i]=='mrudula':
        break
    print(names[i],end=" ")
# Out:
# poojitha

# %% [markdown]
# ## Sets
#
# ![image.png](attachment:image.png)

# %%
s = {1,11,45,1,76,89,23,11,89}
print(s)
# Out:
# {1, 11, 76, 45, 23, 89}

# %%
s.add(10)

# %%
s
# Out:
# {1, 10, 11, 23, 45, 76, 89, 100}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %% [markdown]
# ## Dictionaries
#
# ![image.png](attachment:image.png)
